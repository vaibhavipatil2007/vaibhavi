# %%
 # Import libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install matplotlib
# !pip install seaborn

# %%
# line plot 
x=[1,2,3,4,5]
y=[10,45,56,78,56]
plt.plot(x,y)
plt.title("Line plot")
plt.xlabel("data1")
plt.ylabel("data2")
plt.show()

# %%
#bar plot

data = pd.DataFrame({
    "class": ['A', 'B', 'C', 'D', 'E'],
    "student": [90, 46, 35, 67, 55]
})

sns.barplot(x="class", y="student", data=data)
plt.title("Barplot")
plt.show()

# %%
# count plot 
sns.countplot(x='class',data=data)
plt.title("count plot")
plt.show()

# %%
#Histogram
data = np.random.random(100)  # Corrected typo
plt.hist(data, bins=10)
plt.title("Histogram")
plt.show()  # Corrected typo

# %%
# KDE plot 

sns.kdeplot(data,shade=True)
plt.title("KDE plot")
plt.show()
# Out:
# C:\Users\ATHARVA MALAVI\AppData\Local\Temp\ipykernel_3328\2513910916.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data,shade=True)

# %%
# box plot 

sns.boxplot(y=data)
plt.title("Box  plot")
plt.show()

# %%
# violin plot (box plot + KDE)

sns.violinplot(y=data)
plt.title("violin plot")
plt.show()

# %%
# scatter plot (to show connections, correction between 2 variable )

x=[1,2,3,4,5]
y=[5,4,7,10,8]
plt.scatter(x,y)
plt.title ("scatter plot")

# %%
# seaborn way 
sns.scatterplot(x=x,y=y)
plt.title ("scatter plot")
plt.show()

# %%
# heatmap (to show intercorrelation between numerical variable )

data = pd.DataFrame({
    'A': [1, 2, 3, 4],
    'B': [4, 3, 2, 1],
    'C': [2, 3, 2, 3]
})
correlation_matrix = data.corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['A', 'B', 'C']
sizes = [30, 50, 20]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=0)
plt.title("Pie Chart")
plt.show()

# %%
# rug plot (which shows density within data point)
sns.rugplot(data)
plt.title("rug plot")
plt.show()
