# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
ds = pd.read_csv('employee_dataset_for_eda.csv')

# %%
ds=pd.read_csv("employee_dataset_for_eda.csv")
ds
# Out:
#      Employee_ID  Age  Gender   Department       Location  \
# 0           1001   50  Female    Marketing         Austin
# 1           1002   36  Female        Sales       New York
# 2           1003   29    Male    Marketing  San Francisco
# 3           1004   42  Female           HR  San Francisco
# 4           1005   40  Female    Marketing         Austin
# ..           ...  ...     ...          ...            ...
# 195         1196   40  Female           HR       New York
# 196         1197   41    Male      Finance  San Francisco
# 197         1198   53    Male           HR       New York
# 198         1199   28  Female           HR         Austin
# 199         1200   54    Male  Engineering         Austin
#
#      Years_of_Experience  Monthly_Salary  Performance_Score
# 0                      4          105046               79.6
# 1                      1           59287               71.7
# 2                      5           69711               87.2
# 3                      1           41954               74.4
# 4                     12          103340               82.5
# ..                   ...             ...                ...
# 195                   12           93230               67.3
# 196                    9          104055               58.3
# 197                   17           86373               62.6
# 198                    7           61480               60.7
# 199                    7          115230               75.9
#
# [200 rows x 8 columns]

# %%
# employee  count per deparment  

import seaborn as sns
import matplotlib.pyplot as plt

# employee count per department  
sns.countplot(data=ds, x='Department', palette='Set2') 
plt.title('Employee Count per Department')
plt.xticks(rotation=45)  # Optional, f
# Out:
# C:\Users\ATHARVA MALAVI\AppData\Local\Temp\ipykernel_15864\2232613364.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds, x='Department', palette='Set2')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Marketing'),
#   Text(1, 0, 'Sales'),
#   Text(2, 0, 'HR'),
#   Text(3, 0, 'Engineering'),
#   Text(4, 0, 'Finance')])

# %%
# Finance Department having more employee count followed by marketing and engineering

# %%
sns.countplot(data=ds, x='Gender', palette='coolwarm')  # Corrected palette name
plt.title('Gender Distribution')
plt.show()
# Out:
# C:\Users\ATHARVA MALAVI\AppData\Local\Temp\ipykernel_15864\1624933415.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds, x='Gender', palette='coolwarm')  # Corrected palette name

# %%
sns.countplot(data=ds, x='Location', palette='Spectral')
plt.title('Number of Employees by Location')
plt.xticks(rotation=45)  # Correct usage
plt.show()
# Out:
# C:\Users\ATHARVA MALAVI\AppData\Local\Temp\ipykernel_15864\231212232.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds, x='Location', palette='Spectral')

# %%
# age distribution 

sns.histplot(ds['Age'],bins=10,kde=True)
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
print(ds.columns)
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Location',
#        'Years_of_Experience', 'Monthly_Salary', 'Performance_Score'],
#       dtype='object')

# %%
# years of Experince Distribution 

sns.histplot(ds['Years_of_Experience'], bins=15, kde=True)
plt.title('Years_of_Experience')
# Out:
# Text(0.5, 1.0, 'Years_of_Experience')

# %%
# Monthly salary distribution 

sns.boxplot(data=ds,y='Monthly_Salary',color='lightblue')
plt.title('salary spread')
# Out:
# Text(0.5, 1.0, 'salary spread')

# %%
minimum salary is near about 20,0000
maximum salary is near about 120000

# %%
# Average salary by department 
sns.barplot(data=ds,x='Department',y='Monthly_Salary',estimator=np.mean,palette='viridis')
plt.title('Average salary by Department')
# Out:
# C:\Users\ATHARVA MALAVI\AppData\Local\Temp\ipykernel_17912\3061453224.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ds,x='Department',y='Monthly_Salary',estimator=np.mean,palette='viridis')
# Text(0.5, 1.0, 'Average salary by Department')

# %%
# Performance Score by Department 

sns.boxplot(data=ds,x='Department',y='Performance_Score',palette='pastel')
plt.title('Performance Score by Department')
# Out:
# C:\Users\ATHARVA MALAVI\AppData\Local\Temp\ipykernel_17912\1633574558.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=ds,x='Department',y='Performance_Score',palette='pastel')
# Text(0.5, 1.0, 'Performance Score by Department')

# %%
# salary Distribution by Gender 

sns.violinplot(data=ds,x='Gender',y='Monthly_Salary',palette='muted')
plt.title('Salary by Gender')
# Out:
# C:\Users\ATHARVA MALAVI\AppData\Local\Temp\ipykernel_17912\4247378237.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=ds,x='Gender',y='Monthly_Salary',palette='muted')
# Text(0.5, 1.0, 'Salary by Gender')

# %%
print(ds.columns)
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Location',
#        'Years_of_Experience', 'Monthly_Salary', 'Performance_Score'],
#       dtype='object')

# %%
sns.heatmap( ds[['Age', 'Years_of_Experience', 'Monthly_Salary', 'Performance_Score']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
print(ds.columns)
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Location',
#        'Years_of_Experience', 'Monthly_Salary', 'Performance_Score'],
#       dtype='object')

# %%
# salary vs Experince scatter plot 

sns.scatterplot(data=ds,x='Years_of_Experience',y='Monthly_Salary',hue='Department')
plt.title('salary vs.Experience by Department')
# Out:
# Text(0.5, 1.0, 'salary vs.Experience by Department')
